# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import cvzone
import numpy as np
import pytesseract
from datetime import datetime

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

model = YOLO('best.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        point = [x, y]
        print(point)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('video.mp4')

my_file = open("images\classes.txt", "r")
data = my_file.read()
class_list = data.split("\n") 

# area = [(27, 417), (16, 456), (1015, 451), (992, 417)]
area = [(305, 1025), (1748, 1031), (1800, 1328), (276, 1296)]
count = 0
list1 = []
processed_numbers = set()

# Open file for writing car plate data
with open("car_plate_data.txt", "a") as file:
    file.write("NumberPlate\t\t\tDate\t\t\tTime\n")  # Writing column headers

while True:    
    ret, frame = cap.read()
    count += 1
    # if count % 3 != 0:
    #     continue
    if not ret:
       break
   
    frame = cv2.resize(frame, (1020, 500))
    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.cpu()
    px = pd.DataFrame(a).astype("float")
   
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        
        d = int(row[5])
        c = class_list[d]
        cx = int(x1 + x2) // 2
        cy = int(y1 + y2) // 2
        result = cv2.pointPolygonTest(np.array(area, np.int32), ((cx, cy)), False)
        if result >= 0:
           crop = frame[y1:y2, x1:x2]
           gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
           gray = cv2.bilateralFilter(gray, 10, 20, 20)

           text = pytesseract.image_to_string(gray).strip()
           text = text.replace('(', '').replace(')', '').replace(',', '')
           if text not in processed_numbers:
              processed_numbers.add(text) 
              list1.append(text)
              current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
              with open("car_plate_data.txt", "a") as file:
                   file.write(f"{text}\t{current_datetime}\n")
                   cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 1)
                   cv2.imshow('crop', crop)

      
    cv2.polylines(frame, [np.array(area, np.int32)], True, (255, 0, 0), 2)
    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()    
cv2.destroyAllWindows()
# Out:
# 0: 320x640 (no detections), 93.7ms
# Speed: 6.4ms preprocess, 93.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [90, 64]
# [90, 64]
#
# 0: 320x640 (no detections), 68.9ms
# Speed: 3.7ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.7ms
# Speed: 1.9ms preprocess, 66.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 71.0ms
# Speed: 1.8ms preprocess, 71.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 67.9ms
# Speed: 1.9ms preprocess, 67.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 65.2ms
# Speed: 1.8ms preprocess, 65.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 64.2ms
# Speed: 1.8ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 67.0ms
# Speed: 1.9ms preprocess, 67.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 67.0ms
# Speed: 1.9ms preprocess, 67.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 65.9ms
# Speed: 1.9ms preprocess, 65.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 66.0ms
# Speed: 1.5ms preprocess, 66.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 66.4ms
# Speed: 1.9ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate,
5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 56.9ms
# Speed: 1.9ms preprocess, 56.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 59.0ms
# Speed: 1.8ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 58.4ms
# Speed: 1.8ms preprocess, 58.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 57.7ms
# Speed: 1.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 61.6ms
# Speed: 2.1ms preprocess, 61.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [539, 132]
# [551, 135]
#
# 0: 320x640 1 car_plate, 60.3ms
# Speed: 1.9ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [574, 143]
#
# 0: 320x640 1 car_plate, 60.5ms
# Speed: 3.5ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [578, 137]
#
# 0: 320x640 1 car_plate, 59.8ms
# Speed: 1.7ms preprocess, 59.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [667, 105]
#
# 0: 320x640 1 car_plate, 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [719, 94]
#
# 0: 320x640 1 car_plate, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [720, 93]
#
# 0: 320x640 1 car_plate, 58.6ms
# Speed: 2.5ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 56.9ms
# Speed: 2.2ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 61.5ms
# Speed: 1.9ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [855, 70]
#
# 0: 320x640 1 car_plate, 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [891, 65]
# [892, 64]
#
# 0: 320x640 1 car_plate, 62.0ms
# Speed: 1.7ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [913, 58]
# [916, 57]
#
# 0: 320x640 1 car_plate, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [941, 49]
#
# 0: 320x640 1 car_plate, 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [948, 44]
#
# 0: 320x640 1 car_plate, 64.6ms
# Speed: 1.7ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [985, 25]
#
# 0: 320x640 1 car_plate, 59.6ms
# Speed: 2.2ms preprocess, 59.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [1000, 17]
# [1001, 17]
#
# 0: 320x640 1 car_plate, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [1006, 13]
# [1007, 12]
#
# 0: 320x640 1 car_plate, 67.4ms
# Speed: 2.1ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [1008, 6]
#
# 0: 320x640 1 car_plate, 62.2ms
# Speed: 1.6ms preprocess, 62.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# [1008, 2]
#
# 0: 320x640 1 car_plate, 61.1ms
# Speed: 1.9ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 62.3ms
# Speed: 1.4ms preprocess, 62.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.6ms
# Speed: 2.1ms preprocess, 59.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.6ms
# Speed: 2.2ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.5ms
# Speed: 2.5ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 56.4ms
# Speed: 2.2ms preprocess, 56.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 57.2ms
# Speed: 1.4ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.2ms
# Speed: 1.5ms preprocess, 58.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.2ms
# Speed: 2.2ms preprocess, 59.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.6ms
# Speed: 1.9ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 56.4ms
# Speed: 2.2ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.0ms
# Speed: 1.9ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 56.1ms
# Speed: 1.8ms preprocess, 56.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.0ms
# Speed: 2.1ms preprocess, 60.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.3ms
# Speed: 2.2ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 57.9ms
# Speed: 1.8ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.4ms
# Speed: 4.3ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 62.3ms
# Speed: 2.1ms preprocess, 62.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 57.6ms
# Speed: 2.1ms preprocess, 57.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.4ms
# Speed: 2.0ms preprocess, 58.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.8ms
# Speed: 1.5ms preprocess, 58.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.3ms
# Speed: 2.3ms preprocess, 67.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.3ms
# Speed: 2.1ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 60.9ms
# Speed: 2.2ms preprocess, 60.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 59.9ms
# Speed: 3.2ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 59.9ms
# Speed: 1.9ms preprocess, 59.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 car_plates, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 59.0ms
# Speed: 1.5ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 60.0ms
# Speed: 3.2ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 car_plates, 61.8ms
# Speed: 2.1ms preprocess, 61.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 car_plates, 59.3ms
# Speed: 2.1ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 car_plates, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 55.4ms
# Speed: 1.9ms preprocess, 55.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 60.5ms
# Speed: 1.7ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 car_plates, 62.4ms
# Speed: 1.5ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 53.5ms
# Speed: 2.4ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 60.0ms
# Speed: 2.2ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 53.9ms
# Speed: 2.3ms preprocess, 53.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 60.2ms
# Speed: 2.1ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 57.1ms
# Speed: 2.2ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 56.2ms
# Speed: 2.2ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car_plate, 62.8ms
# Speed: 2.1ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
